# %%
import yfinance as yf
import pandas_datareader.data as pdr
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Flatten
from keras import backend as K
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import sqlite3
import pandas as pd
import math
import matplotlib.pyplot as plt
plt.style.use('seaborn')
from datetime import datetime
yf.pdr_override()

#For reproducability
from numpy.random import seed
seed(1)
tf.random.set_seed(2)
# Out:
# /var/folders/9m/qcg58ft12w72z4h1j7s196w00000gn/T/ipykernel_63281/3611856973.py:15: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## Data processing

# %%
# Some functions to help out with
def plot_predictions(test,predicted,symbol):
    plt.plot(test, color='red',label=f'Real {symbol} Stock Price')
    plt.plot(predicted, color='blue',label=f'Predicted {symbol} Stock Price')
    plt.title(f'{symbol} Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel(f'{symbol} Stock Price')
    plt.legend()
    plt.show()

def plot_return_predictions(test,predicted,symbol):
    plt.plot(test, color='red',label=f'Real {symbol} Stock Price Returns')
    plt.plot(predicted, color='blue',label=f'Predicted {symbol} Stock Price Return')
    plt.title(f'{symbol} Stock Return Prediction')
    plt.xlabel('Time')
    plt.ylabel(f'{symbol} Stock Price Returns')
    plt.legend()
    plt.show()
    
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

def get_ticker_data(ticker: str, param_start_date, param_end_date) -> tuple:
    # Fetch data from Yahoo Finance
    data = pdr.get_data_yahoo(ticker, start=param_start_date, end=param_end_date)
    data.reset_index(inplace=True)
    data = data.fillna(method="ffill", axis=0)
    data = data.fillna(method="bfill", axis=0)
    
    # Prepare the data
    prices = data["Close"].values.reshape(-1, 1)
    
    # Scale the data
    scaler = MinMaxScaler(feature_range=(-1, 1))
    prices = scaler.fit_transform(prices)
    
    # Create sequences
    SEQ_LEN = 8 # I assumed the sequence length, you can change this value as per your requirements
    inputs, targets = [], []
    for i in range(SEQ_LEN, len(prices) - 1):
        inputs.append(prices[i - SEQ_LEN:i])
        targets.append(prices[i + 1])

    return data, np.array(inputs), np.array(targets)

def fetch_ticker_data(ticker: str, start_date, end_date) -> tuple:
    return get_ticker_data(ticker, start_date, end_date)
def shift(xs, n):
    e = np.empty_like(xs)
    if n >= 0:
        e[:n] = np.nan
        e[n:] = xs[:-n]
    else:
        e[n:] = np.nan
        e[:n] = xs[-n:]
    return e

#Scaled Exponentially-Regularized Linear Unit to try out - if anyone can make this work, let me know.

# def serlu(x, lambdaa=1.07862, alphaa=2.90427):
#     result = tf.cond(x >= 0, lambda: tf.math.multiply(lambdaa, x), lambda: tf.math.multiply(lambdaa, alphaa, x, tf.exp(x)))
#     return result

# %% [markdown]
# # Get the Data

# %%
# Example usage:

symbol_to_fetch = 'IBM'
start_date = '2020-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')
stock, inputs, targets = fetch_ticker_data(symbol_to_fetch, start_date, end_date)
stock.columns = ['DateTime', 'High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close']
stock['DateTime'] = pd.to_datetime(stock['DateTime'])
stock.set_index('DateTime', inplace=True)
stock['Symbol'] = symbol_to_fetch

#save a copy for later testing
original_stock = stock
original_symbol = symbol_to_fetch

# print(stock_df.tail())
# print(inputs[-5:], targets[-5:])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Choose a stock symbol
symbol_to_fetch = 'IBM'
# Choose a date range
start_date = str(datetime(2017, 1, 1).date())
end_date = str(datetime(2021, 2, 18).date())
# end_date = datetime.now().strftime('%Y-%m-%d')

# %%
# We have chosen the target as 'Close' attribute for prices. Let's see what it looks like
target = 'Close' # this is accessed by .iloc[:,3:4].values below
train_start_date = start_date
train_end_date = '2021-10-31'
test_start_date = '2021-11-01'
training_set = stock[train_start_date:train_end_date].iloc[:,3:4].values 
test_set = stock[test_start_date:].iloc[:,3:4].values

test_set_return = stock[test_start_date:].iloc[:,3:4].pct_change().values
#log_return_test = np.log(test_set_return)

print(training_set.shape)
print(test_set.shape)
# Out:
# (462, 1)
# (400, 1)

# %%
# #let's try adding multiple stocks in the training set... Like everything in the SPY holdings to see if that improves our target
# connection = sqlite3.connect('../input/spy-stocks/spy.db')
# connection.row_factory = sqlite3.Row
# cursor = connection.cursor()
# cursor.execute("""
#     SELECT symbol FROM stocks
# """)
# rows = cursor.fetchall()
# for row in rows:
#     try:
#         symbol = row['symbol']
#         print (symbol)
#         symbol_to_fetch = symbol
#         stock = fetch_ticker_data(symbol_to_fetch, start_date, end_date)
#         stock.columns = ['DateTime', 'Open', 'High', 'Low', 'Close', 'Volume']
#         stock['DateTime'] = stock['DateTime'].apply(lambda x: datetime.fromtimestamp(x))
#         stock = stock.fillna(method="ffill", axis=0)
#         stock = stock.fillna(method="bfill", axis=0)
#         stock = stock.set_index('DateTime')
#         new_training_set = stock[train_start_date:train_end_date].iloc[:,3:4].values
#         frames = [training_set, new_training_set]
#         training_set = np.concatenate(frames, axis = 0)
#     except:
#         continue
# print(training_set.shape)
# # This works best with a TPU and trains very fast so only around 10 epochs needed due to the 1.8 million sample.
# # Also it is possible to sort by sector - just add (WHERE sector = 'Information Technology') under
# # the SELECT line.

# %%
stock[target][train_start_date:train_end_date].plot(figsize=(16,4),legend=True)
stock[target][test_start_date:].plot(figsize=(16,4),legend=True)
plt.legend([f'Training set (Before {train_end_date})',f'Test set ({test_start_date} and beyond)'])
plt.title(f'{symbol_to_fetch} stock price')
plt.show()

# %%
# Scaling the training set - I've tried it without scaling and results are very poor.
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
timesteps = 8
# First, we create data sets where each sample has with 8 timesteps and 1 output
# So for each element of training set, we have 8 previous training set elements 
x_train = []
y_train = []
for i in range(timesteps,training_set.shape[0]):
    x_train.append(training_set_scaled[i-timesteps:i,0])
    y_train.append(training_set_scaled[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

print(x_train[0], y_train[0])
print(x_train[1], y_train[1])

# Notice how the first y_train value becomes the last X_train value for the next sample
# Out:
# [0.65575105 0.63832894 0.63445734 0.63590896 0.65397655 0.67704477
#  0.67623811 0.67478622] 0.6622035595002569
# [0.63832894 0.63445734 0.63590896 0.65397655 0.67704477 0.67623811
#  0.67478622 0.66220356] 0.6751090909278161

# %% [markdown]
# ### The choice of the number of timesteps is the first thing worth noting. This is also true with RNNs, but with transformers - the optimum choice is often much lower. Three stocks are shown below. With RNNs the number ranges much higher. For ConvLSTMs the optimum is usually between 40-90 timesteps, with transformers it is usually under 10.
# ![Rmse_by_timestep.png](attachment:ad1bbf60-ca20-47f2-8870-24c056ff7f44.png)

# %%
print(x_train.shape, y_train.shape)
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
print(x_train.shape, y_train.shape)
# Out:
# (454, 8) (454,)
# (454, 8, 1) (454,)

# %%
print(x_train.shape, y_train.shape)
# Interestingly - randomly arranging the samples works well, since we are using validation_split = 0.2, (rather then validation_data = )
# It is worth looking into whether using a K-fold would work better - if so would not use random permutation.
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]
# Out:
# (454, 8, 1) (454,)

# %% [markdown]
# # Build the model
#
# ### Our model processes a tensor of shape [batch size, sequence length, features], where sequence length is the number of time steps in your sample and features is the number of elements you are trying to predict. If we are only trying to predict one thing, such as closing price - then features is 1. When it comes to describing tensor shapes, I am going to refer to batch size as "#samples" so as not to confuse it with batch_size when fitting the model.
#
# ### Fortunately, with recurrent neural nets (such as LSTMs) for timeseries analysis, the inputs [#samples, timesteps, features] are compatible with transformers!
# #### The image below is for a single transformer encoder block. For our purposes, the embedding is removed and limited to only to a LayerNormalization layer (which does work better than a BatchNormalization layer). The positional embedding is an option, but frankly - I have tried three diferent time2vec implementations and although the code works, the results are worse (If you can implement a time2vec function which actually improves the rmse score then please share with me). The multi-head attention is already coded for in keras. The feed forward part can be almost anything. We will use a Conv1D layer(because results are good) but you could get away with almost anything, dense layers, another LSTM, whatever you want. You could also stick an LSTM in the embedding layer - it works, if your return_sequences = True, it just give worse results.

# %% [markdown]
# <center><img src = "data:image/png;base64,..."></center>

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    
    # Normalization and Attention
    # "EMBEDDING LAYER"
    print(f'inputs.shape = {inputs.shape}')
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    print(f'x.shape after LayerNormalization = {x.shape}')
    
    # "ATTENTION LAYER"
    print(f'head_size = {head_size} num_heads = {num_heads} dropout = {dropout}')
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    print(f'x.shape after MultiHeadAttention = {x.shape}')
    x = layers.Dropout(dropout)(x)
    res = x + inputs
    print(f'res.shape after res = {res.shape}')
    
    # FEED FORWARD Part - you can stick anything here or just delete the whole section - it will still work. 
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    print(f'x.shape after LayerNormalization = {x.shape}')
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation = "relu")(x)
    print(f'x.shape after Conv1D = {x.shape}')
    x = layers.Dropout(dropout)(x)
    print(f'x.shape after Dropout = {x.shape}')
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    print(f'x.shape after Conv1D = {x.shape}')
    return x + res

# %% [markdown]
# ### The main part of our model is now complete.
# ### We can stack multiple of those transformer_encoder blocks and we can also proceed to add the final Multi-Layer Perceptron/ DNN head.
#
# ### Apart from a stack of Dense layers, we need to reduce the output tensor of the TransformerEncoder part of our model down to a vector of features for each data point in the current batch. A pooling layer like GlobalAveragePooling1D layer will do this.
# GlobalAveragePooling1D input shape is [#samples, timesteps, features] (if channels_first format is chosen), its default output is [#samples, timesteps].

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    print(f'Input shape: {x.shape}')  # Print input shape

    for _ in range(num_transformer_blocks):  # This is what stacks our transformer blocks
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)
        print(f'Transformer block output shape: {x.shape}')  # Print transformer block output shape

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    print(f'Pooled output shape: {x.shape}')  # Print pooled output shape

    for dim in mlp_units:
        x = layers.Dense(dim, activation="elu")(x)
        print(f'After Dense layer shape: {x.shape}')  # Print shape after Dense layer
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1, activation="linear")(x)  # this is a pass-through
    print(f'Final output shape: {outputs.shape}')  # Print final output shape
    return keras.Model(inputs, outputs)

# %% [markdown]
# ### Another note - the activation function above makes a difference, elu is best : elu > selu > tanh > relu > gelu > swish. I am curious if serlu would out perform them but I can't figure out how to add the custom activation function.

# %%
def lr_scheduler(epoch, lr, warmup_epochs=30, decay_epochs=100, initial_lr=1e-6, base_lr=1e-3, min_lr=5e-5):
    if epoch <= warmup_epochs:
        pct = epoch / warmup_epochs
        return ((base_lr - initial_lr) * pct) + initial_lr

    if epoch > warmup_epochs and epoch < warmup_epochs+decay_epochs:
        pct = 1 - ((epoch - warmup_epochs) / decay_epochs)
        return ((base_lr - min_lr) * pct) + min_lr

    return min_lr

# This learning rate scheduler is also from Mr. Theodoros Ntakouris' articla at https://towardsdatascience.com/the-time-series-transformer-2a521a0efad3
# I am definetely a fan.

# %%
callbacks = [
            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
            keras.callbacks.LearningRateScheduler(lr_scheduler)
            ]

# %%
input_shape = x_train.shape[1:]
print(input_shape)
# Out:
# (8, 1)

# %%
model = build_model(
    input_shape,
    head_size=46,  # Embedding size for attention
    num_heads=60,  # Number of attention heads
    ff_dim=55,  # Hidden layer size in feed forward network inside transformer
    num_transformer_blocks=2,
    mlp_units=[256],
    mlp_dropout=0.4,
    dropout=0.14,
)

model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["mean_squared_error"],
)
#model.summary()

history = model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=20,
    callbacks=callbacks,
)
# Out:
# Input shape: (None, 8, 1)
# inputs.shape = (None, 8, 1)
# x.shape after LayerNormalization = (None, 8, 1)
# head_size = 46 num_heads = 60 dropout = 0.14
# x.shape after MultiHeadAttention = (None, 8, 1)
# res.shape after res = (None, 8, 1)
# x.shape after LayerNormalization = (None, 8, 1)
# x.shape after Conv1D = (None, 8, 55)
# x.shape after Dropout = (None, 8, 55)
# x.shape after Conv1D = (None, 8, 1)
# Transformer block output shape: (None, 8, 1)
# inputs.shape = (None, 8, 1)
# x.shape after LayerNormalization = (None, 8, 1)
# head_size = 46 num_heads = 60 dropout = 0.14
# x.shape after MultiHeadAttention = (None, 8, 1)
# res.shape after res = (None, 8, 1)
# x.shape after LayerNormalization = (None, 8, 1)
# x.shape after Conv1D = (None, 8, 55)
# x.shape after Dropout = (None, 8, 55)
# x.shape after Conv1D = (None, 8, 1)
# Transformer block output shape: (None, 8, 1)
# Pooled output shape: (None, 8)
# After Dense layer shape: (None, 256)
# Final output shape: (None, 1)
# Epoch 1/100
# 19/19 [==============================] - 1s 22ms/step - loss: 0.7767 - mean_squared_error: 0.7767 - val_loss: 0.7568 - val_mean_squared_error: 0.7568 - lr: 1.0000e-06
# Epoch 2/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.6810 - mean_squared_error: 0.6810 - val_loss: 0.5782 - val_mean_squared_error: 0.5782 - lr: 3.4300e-05
# Epoch 3/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.4980 - mean_squared_error: 0.4980 - val_loss: 0.3764 - val_mean_squared_error: 0.3764 - lr: 6.7600e-05
# Epoch 4/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3215 - mean_squared_error: 0.3215 - val_loss: 0.2600 - val_mean_squared_error: 0.2600 - lr: 1.0090e-04
# Epoch 5/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2189 - mean_squared_error: 0.2189 - val_loss: 0.1665 - val_mean_squared_error: 0.1665 - lr: 1.3420e-04
# Epoch 6/100
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1270 - mean_squared_error: 0.1270 - val_loss: 0.0486 - val_mean_squared_error: 0.0486 - lr: 1.6750e-04
# Epoch 7/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0545 - mean_squared_error: 0.0545 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - lr: 2.0080e-04
# Epoch 8/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - lr: 2.3410e-04
# Epoch 9/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - lr: 2.6740e-04
# Epoch 10/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - lr: 3.0070e-04
# Epoch 11/100
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - lr: 3.3400e-04
# Epoch 12/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - lr: 3.6730e-04
# Epoch 13/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - lr: 4.0060e-04
# Epoch 14/100
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - lr: 4.3390e-04
# Epoch 15/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0066 - val_mean_squared_error: 0.0066 - lr: 4.6720e-04
# Epoch 16/100
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - lr: 5.0050e-04
# Epoch 17/100
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - lr: 5.3380e-04
# Epoch 18/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - lr: 5.6710e-04
# Epoch 19/100
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - lr: 6.0040e-04
# Epoch 20/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - lr: 6.3370e-04
# Epoch 21/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0047 - val_mean_squared_error: 0.0047 - lr: 6.6700e-04
# Epoch 22/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - lr: 7.0030e-04
# Epoch 23/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - lr: 7.3360e-04
# Epoch 24/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - lr: 7.6690e-04
# Epoch 25/100
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - lr: 8.0020e-04
# Epoch 26/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - lr: 8.3350e-04
# Epoch 27/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - lr: 8.6680e-04
# Epoch 28/100
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 9.0010e-04
# Epoch 29/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - lr: 9.3340e-04
# Epoch 30/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - lr: 9.6670e-04
# Epoch 31/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - lr: 0.0010
# Epoch 32/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - lr: 9.9050e-04
# Epoch 33/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - lr: 9.8100e-04
# Epoch 34/100
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - lr: 9.7150e-04
# Epoch 35/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - lr: 9.6200e-04
# Epoch 36/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - lr: 9.5250e-04
# Epoch 37/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 9.4300e-04
# Epoch 38/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - lr: 9.3350e-04
# Epoch 39/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 9.2400e-04
# Epoch 40/100
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 9.1450e-04
# Epoch 41/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 9.0500e-04
# Epoch 42/100
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - lr: 8.9550e-04
# Epoch 43/100
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 8.8600e-04
# Epoch 44/100
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - lr: 8.7650e-04
# Epoch 45/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 8.6700e-04
# Epoch 46/100
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 8.5750e-04
# Epoch 47/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 8.4800e-04
# Epoch 48/100
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 8.3850e-04
# Epoch 49/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 8.2900e-04
# Epoch 50/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 8.1950e-04
# Epoch 51/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 8.1000e-04
# Epoch 52/100
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 8.0050e-04
# Epoch 53/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 7.9100e-04
# Epoch 54/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 7.8150e-04
# Epoch 55/100
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 7.7200e-04
# Epoch 56/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 7.6250e-04
# Epoch 57/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 7.5300e-04
# Epoch 58/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 7.4350e-04
# Epoch 59/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 7.3400e-04
# Epoch 60/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 7.2450e-04
# Epoch 61/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - lr: 7.1500e-04
# Epoch 62/100
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - lr: 7.0550e-04
# Epoch 63/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 6.9600e-04
# Epoch 64/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 6.8650e-04
# Epoch 65/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 6.7700e-04
# Epoch 66/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 6.6750e-04
# Epoch 67/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 6.5800e-04
# Epoch 68/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 6.4850e-04
# Epoch 69/100
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 6.3900e-04
# Epoch 70/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 6.2950e-04
# Epoch 71/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - lr: 6.2000e-04
# Epoch 72/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - lr: 6.1050e-04
# Epoch 73/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - lr: 6.0100e-04
# Epoch 74/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 5.9150e-04
# Epoch 75/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 5.8200e-04
# Epoch 76/100
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 5.7250e-04
# Epoch 77/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - lr: 5.6300e-04
# Epoch 78/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 5.5350e-04
# Epoch 79/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 5.4400e-04
# Epoch 80/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - lr: 5.3450e-04
# Epoch 81/100
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 5.2500e-04
# Epoch 82/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 5.1550e-04
# Epoch 83/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - lr: 5.0600e-04
# Epoch 84/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 4.9650e-04
# Epoch 85/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - lr: 4.8700e-04
# Epoch 86/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 4.7750e-04
# Epoch 87/100
# 19/19 [==============================] - 0s 19ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 4.6800e-04
# Epoch 88/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 4.5850e-04
# Epoch 89/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 4.4900e-04
# Epoch 90/100
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 4.3950e-04
# Epoch 91/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - lr: 4.3000e-04
# Epoch 92/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 4.2050e-04
# Epoch 93/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 4.1100e-04
# Epoch 94/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 4.0150e-04
# Epoch 95/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 3.9200e-04
# Epoch 96/100
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 3.8250e-04
# Epoch 97/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 3.7300e-04
# Epoch 98/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 3.6350e-04
# Epoch 99/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 3.5400e-04
# Epoch 100/100
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 3.4450e-04

# %% [markdown]
# # Evaluate model

# %%
# First we have to frontload the test data before the inital values of our test_set

dataset_total = pd.concat((original_stock[target][:train_end_date],original_stock[target][test_start_date:]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - timesteps:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.fit_transform(inputs)

X_test = []
for i in range(timesteps,test_set.shape[0] + timesteps):
    X_test.append(inputs[i-timesteps:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)


print(test_set[-3],test_set[-2], test_set[-1])
shifted_test_set = shift(test_set, 1) #The shift function is defined early in the notebook
print(shifted_test_set[-3],shifted_test_set[-2], shifted_test_set[-1])

print(predicted_stock_price[-1])
prediction_error = test_set - predicted_stock_price # This is the error on the same day
#Before we can calculate the predicted return we have to shift the test_set to the day before so we use the shifted_test_set
predicted_return = (shifted_test_set - predicted_stock_price) / shifted_test_set

plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper left')
plt.show()

plot_predictions(test_set,predicted_stock_price,original_symbol)
return_rmse(test_set,predicted_stock_price)

plot_return_predictions(test_set_return,predicted_return,original_symbol)
return_rmse(test_set_return[1:], predicted_return[1:])
# Out:
# 13/13 [==============================] - 0s 18ms/step
# [129.82000732] [132.41999817] [132.63999939]
# [128.58999634] [129.82000732] [132.41999817]
# [131.31537]
# The root mean squared error is 2.012066924793679.
# The root mean squared error is 0.014308139104392109.
# 0.014308139104392109

# %% [markdown]
# # Points of Consideration
#
# ### 1. The number of timesteps is a critical factor and the optimal number will vary for each stock. But as a whole the optimal number is lower than for RNNs.
# ### 2. Unlike RNN's adding Time2Vec embedding does not improve results.
# ### 3. elu is the best activation for the final DNN/MLP "classification head".
# ### 4. Also - I know that what really counts is predicting returns. However if I use stock['return'] instead of stock['Close'] I get vanishing gradients. If anyone can help me solve THAT problem I would greatly appreciate it.
# ### 5. In the Price and Return graphs above - there is always a lag, that is expected - but unfortunately it is also very unprofitable. If one ever hopes to apply this - one has to be able to minimize losses, by predicting price reversals. I have tried to apply the same model to predict whether there is a reversal and it works ! but only 50.000 % of the time.

# %% [markdown]
# # Can we use technical indicators to predict reversal?
# ### Fortunataley our database has them precalculated.
